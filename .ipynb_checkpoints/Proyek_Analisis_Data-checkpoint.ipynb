# %% [markdown]
# # Data Analysis Project: [Brazilian E-Commerce Dataset]
# - **Name:** Aniqoh Hana Haura
# - **Email:** hana.haura06@gmail.com
# - **ID Dicoding:** Aniqoh Hana Haura

# %% [markdown]
# ## Defining Business Questions

# %% [markdown]
# 1. How many customers from 2016 to 2018?
# 2. How many orders from 2016 to 2018?
# 3. What was the total revenue from 2016 to 2018?
# 4. What was the most purchased product category from 2016 to 2018?
# 5. What was the most used payment method from 2016 to 2018?
# 6. What is the distribution of review scores from 2016 to 2018?

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# There are 7 datasets: customers dataset, orders dataset, order items dataset, order payments dataset, order reviews dataset, products dataset, and product category name translation dataset.

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Customers Dataset

# %%
customers_df = pd.read_csv('C:/Users/aniqo/Projects/Submission/data/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **Insight:**
# - customer_id is the key for the order dataset. Each order has a unique customer_id.
# - customer_unique_id is a unique identifier for each customer.
# - customer_zip_code_prefix references to the first five digits of the customer's postcode.
# - customer_city a reference to the customer's city name.
# - customer_state a reference to the customer's state.

# %%
orders_df = pd.read_csv('C:/Users/aniqo/Projects/Submission/data/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **Insight:**
# - order_id is a unique identifier for each order.
# - customer_id is the key to the customer dataset. Each order has a unique customer_id.
# - order_status reference to the order status (invoiced/created/approved/processing/shipped/delivered/unavailable/canceled).
# - order_purchase_timestamp shows the purchase timestamp.
# - order_approved_at shows the payment approval timestamp.
# - order_delivered_carrier_date shows the order posting timestamp. When it was handled to the logistic partner.
# - order_delivered_customer_date shows the actual order delivery date to the customer.
# - order_estimated_delivery_date shows the estimated delivery date that was informed to customer at the purchase moment.

# %% [markdown]
# #### Products Dataset

# %%
products_df = pd.read_csv('C:/Users/aniqo/Projects/Submission/data/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# **Insight:**
# - product_id is a unique identifier for each product.
# - product_category_name in Portuguese.
# - product_name_length is a number of characters extracted from the product name.
# - product_description_length is a number of characters extracted from the product description.
# - product_photos_qty is a number of product published photos.
# - product_weight_g is a product weight measured in grams.
# - product_length_cm is a product length measured in centimeters.
# - product_height_cm is a product height measured in centimeters.
# - product_width_cm is a product width measured in centimeters.

# %% [markdown]
# #### Product Category Name Translation Dataset

# %%
product_category_name_t_df = pd.read_csv('C:/Users/aniqo/Projects/Submission/data/product_category_name_translation.csv')
product_category_name_t_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# **Insight:**
# - product_category_name in Portuguese.
# - product_category_name_english in English

# %% [markdown]
# #### Order Items Dataset

# %%
oitems_df = pd.read_csv('C:/Users/aniqo/Projects/Submission/data/order_items_dataset.csv')
oitems_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **Insight:**
# - order_id is a unique identifier of the order.
# - order_item_id is a sequential number identifying number of items included in the same order.
# - product_id is the key to the products dataset.
# - seller_id is the key to the sellers dataset.
# - shipping_limit_date shows the seller shipping limit date for handling the order over to the logistic partner.
# - price refrenece to the item price.
# - freight_value reference to the freight value (if an order has more than one item the freight value is splitted between items).

# %% [markdown]
# #### Order Payments Dataset

# %%
opayments_df = pd.read_csv('C:/Users/aniqo/Projects/Submission/data/order_payments_dataset.csv')
opayments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# **Insight:**
# - order_id is a key to the orders dataset.
# - payment_sequential, a customer may pay an order with more than one payment method. If he does so, a sequence will be created to.
# - payment_type reference to the method of payment chosen by the customer.
# - payment_installments is a number of installments chosen by the customer.
# - payment_value reference to transaction value.

# %% [markdown]
# #### Order Reviews Dataset

# %%
oreviews_df = pd.read_csv('C:/Users/aniqo/Projects/Submission/data/order_reviews_dataset.csv')
oreviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# **Insight:**
# - review_id is a unique identifier for each review.
# - order_id is the key to the orders dataset.
# - review_score reference to customer satisfaction level, from 1-5.
# - review_comment_title is a comment title from the review left by the customer, in Portuguese.
# - review_comment_message is a comment message from the review left by the customer, in Portuguese.
# - review_creation_date shows the date in which the satisfaction survey was sent to the customer.
# - review_answer_timestamp shows satisfaction survey answer timestamp.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Customers Dataset

# %%
# identify number of rows and columns, data types
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
# identify missing values 
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
# identify data duplicate
customers_df.duplicated().sum()
# Out:
# 0

# %%
# identify outliers
plt.figure(figsize=(4,4))
plt.boxplot(customers_df.select_dtypes(include='number'))
plt.title("Numerical Variable Distribution")
plt.show()

# %% [markdown]
# **Insight :** Customer dataset does not contain missing values, duplicate data, and outlier data.

# %% [markdown]
# #### Orders Dataset

# %%
# identify number of rows and columns, data types
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# converts the data type of the object to date-time
date_time_columns = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date',
                 'order_delivered_customer_date', 'order_estimated_delivery_date']

for column in date_time_columns:
    orders_df[column] = pd.to_datetime(orders_df[column], format='%Y-%m-%d %H:%M:%S')    

print(orders_df.dtypes)
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
# identify missing values 
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
# identify data duplicate
orders_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Insight:** Orders dataset does not contain duplicate data but 3 features contain missing values.

# %% [markdown]
# #### Products Dataset

# %%
# identify number of rows and columns, data types
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
# identify missing values  
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# identify data duplicate
products_df.duplicated().sum()
# Out:
# 0

# %%
# identify outliers
for col in products_df.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(products_df[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insight:** Products dataset does not contain duplicate data but 8 features contain missing values and 7 features contain outliers.

# %% [markdown]
# #### Product Category Name Translation Dataset

# %%
# identify number of rows and columns, data types
product_category_name_t_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
# identify missing values
product_category_name_t_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
# identify data duplicate
product_category_name_t_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Insight:**
# Product category name translation dataset does not contain missing values and duplicate data.

# %% [markdown]
# #### Order Items Dataset

# %%
# identify number of rows and columns, data types
oitems_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# converts the data type of the object to date-time
oitems_df['shipping_limit_date'] = pd.to_datetime(oitems_df['shipping_limit_date'], format='%Y-%m-%d %H:%M:%S')
print(oitems_df.dtypes)
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %%
# identify missing values
oitems_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
# identify data duplicate
oitems_df.duplicated().sum()
# Out:
# 0

# %%
# identify outliers
for col in oitems_df.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(oitems_df[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insight:** Order items dataset does not contain missing values and duplicate data, but 3 features contain outliers.

# %% [markdown]
# #### Order Payments Dataset

# %%
# identify number of rows and columns, data types
opayments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
# identify missing values
opayments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
# identify data duplicate
opayments_df.duplicated().sum()
# Out:
# 0

# %%
# identify outliers
for col in opayments_df.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(opayments_df[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insight:** Order payments dataset does not contain missing values and duplicate data, but 3 features contain outliers.

# %% [markdown]
# #### Order Reviews Dataset

# %%
# identify number of rows and columns, data types
oreviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
# converts the data type of the object to date-time
date_time_columns = ['review_creation_date', 'review_answer_timestamp']

for column in date_time_columns:
    oreviews_df[column] = pd.to_datetime(oreviews_df[column], format='%Y-%m-%d %H:%M:%S')

print(oreviews_df.dtypes)
# Out:
# review_id                          object
# order_id                           object
# review_score                        int64
# review_comment_title               object
# review_comment_message             object
# review_creation_date       datetime64[ns]
# review_answer_timestamp    datetime64[ns]
# dtype: object

# %%
# identify missing values
oreviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
# identify data duplicate
oreviews_df.duplicated().sum()
# Out:
# 0

# %%
# identify outliers
for col in oreviews_df.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(oreviews_df[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insight:** Order reviews dataset does not contain duplicate data, but 2 features contain missing values and 1 feature contain outliers.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Orders Dataset

# %%
# handle missing values with interpolation method
orders_df['order_approved_at'].fillna(method='ffill', inplace=True)
orders_df['order_delivered_carrier_date'].fillna(method='ffill', inplace=True)
orders_df['order_delivered_customer_date'].fillna(method='bfill', inplace=True)

# %%
# recheck missing value
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# **Insight:**
# Orders dataset does not contain missing values.

# %% [markdown]
# #### Products Dataset

# %%
# handle missing values with 'NaN' or mean
products_df['product_category_name'].fillna(value='NaN',inplace=True) 
columns_with_missing_values = ['product_name_lenght', 'product_description_lenght', 'product_photos_qty',
                               'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
for col in columns_with_missing_values:
    products_df[col].fillna(products_df[col].median(), inplace=True)

# %%
# recheck missing value
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
# handle outliers with imputation method
features = ['product_name_lenght', 'product_description_lenght', 'product_photos_qty']

for feature in features:
    Q1 = products_df[feature].quantile(0.25)
    Q3 = products_df[feature].quantile(0.75)
    IQR = Q3 - Q1
    
    maximum = Q3 + (1.5 * IQR)
    minimum = Q1 - (1.5 * IQR)
    
    kondisi_lower_than = products_df[feature] < minimum
    kondisi_more_than = products_df[feature] > maximum
    
    products_df[feature] = products_df[feature].where(~kondisi_more_than, other=maximum)
    products_df[feature] = products_df[feature].where(~kondisi_lower_than, other=minimum)

# %% [markdown]
# **Insight:**
# - Fill missing values with NaN values for categorical columns and median values for numerical columns.
# - Replace the outlier values in the ‘product_name_lenght’, ‘product_description_lenght’, and ‘product_photos_qty’ columns with the minimum or maximum value of the column.
# - Outliers in the columns ‘product_weight_g’, ‘product_length_cm’, ‘product_height_cm’, and ‘product_width_cm’ were left out as they were considered to be specific patterns.

# %% [markdown]
# #### Order Items Dataset

# %%
# identify outliers more deeply to find out whether the outliers are a specific pattern or an error.
# descriptive analysis
oitems_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
# checking order_id for order with order_item_id=21
oitems_df[oitems_df['order_item_id'] == 21]
# Out:
#                                order_id  order_item_id  \
# 57317  8272b63d03f5f79c56e9e4120aec44ef             21
#
#                              product_id                         seller_id  \
# 57317  79ce45dbc2ea29b22b5a261bbb7b7ee7  2709af9587499e95e803a6498a5a56e9
#
#       shipping_limit_date  price  freight_value
# 57317 2017-07-21 18:25:23    7.8           6.57

# %%
# checking product_id, seller_id, price, and freight_value for order with order_id='8272b63d03f5f79c56e9e4120aec44ef' and order_item_id=21
oitems_df[oitems_df['order_id'] == '8272b63d03f5f79c56e9e4120aec44ef']
# Out:
#                                order_id  order_item_id  \
# 57297  8272b63d03f5f79c56e9e4120aec44ef              1
# 57298  8272b63d03f5f79c56e9e4120aec44ef              2
# 57299  8272b63d03f5f79c56e9e4120aec44ef              3
# 57300  8272b63d03f5f79c56e9e4120aec44ef              4
# 57301  8272b63d03f5f79c56e9e4120aec44ef              5
# 57302  8272b63d03f5f79c56e9e4120aec44ef              6
# 57303  8272b63d03f5f79c56e9e4120aec44ef              7
# 57304  8272b63d03f5f79c56e9e4120aec44ef              8
# 57305  8272b63d03f5f79c56e9e4120aec44ef              9
# 57306  8272b63d03f5f79c56e9e4120aec44ef             10
# 57307  8272b63d03f5f79c56e9e4120aec44ef             11
# 57308  8272b63d03f5f79c56e9e4120aec44ef             12
# 57309  8272b63d03f5f79c56e9e4120aec44ef             13
# 57310  8272b63d03f5f79c56e9e4120aec44ef             14
# 57311  8272b63d03f5f79c56e9e4120aec44ef             15
# 57312  8272b63d03f5f79c56e9e4120aec44ef             16
# ...

# %% [markdown]
# From the results above, it can be seen that customers purchased 21 products in 3 different product categories sold by one seller.

# %%
# checking payment_value for order with order_id='8272b63d03f5f79c56e9e4120aec44ef' and order_item_id=21
opayments_df[opayments_df['order_id'] == '8272b63d03f5f79c56e9e4120aec44ef']
# Out:
#                                order_id  payment_sequential payment_type  \
# 71010  8272b63d03f5f79c56e9e4120aec44ef                   1  credit_card
#
#        payment_installments  payment_value
# 71010                     2         196.11

# %% [markdown]
# payment value = price + freight value

# %% [markdown]
# After checking the payment_value for order with order_id='8272b63d03f5f79c56e9e4120aec44ef' and order_item_id=21, it is confirmed that the order is valid. So the outliers in the ‘order_item_id’ column are left as they are considered a certain pattern.

# %%
# checking order_id for order with price=6735
oitems_df[oitems_df['price'] == 6735]
# Out:
#                               order_id  order_item_id  \
# 3556  0812eb902a67711a1cb742b3cdaa65ae              1
#
#                             product_id                         seller_id  \
# 3556  489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
#
#      shipping_limit_date   price  freight_value
# 3556 2017-02-16 20:37:36  6735.0         194.31

# %%
# checking product_category_name and product_weight_g for order with product_id='489ae2aa008f021502940f251d4cce7f' and price=6735
products_df[products_df['product_id'] == '489ae2aa008f021502940f251d4cce7f']
# Out:
#                             product_id  product_category_name  \
# 5899  489ae2aa008f021502940f251d4cce7f  utilidades_domesticas
#
#       product_name_lenght  product_description_lenght  product_photos_qty  \
# 5899                 31.0                       875.0                 2.0
#
#       product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 5899           30000.0               60.0               61.0              33.0

# %%
# checking product_category_name_english for order with product_category_name='utilidades_domesticas' and price=6735
product_category_name_t_df[product_category_name_t_df['product_category_name'] == 'utilidades_domesticas']
# Out:
#    product_category_name product_category_name_english
# 7  utilidades_domesticas                    housewares

# %% [markdown]
# The product with a price of 6735 is a product in the housewares category with a product weight of 30000g (30Kg).

# %%
# checking payment_value for order with order_id='0812eb902a67711a1cb742b3cdaa65ae' and price=6735
opayments_df[opayments_df['order_id'] == '0812eb902a67711a1cb742b3cdaa65ae']
# Out:
#                                order_id  payment_sequential payment_type  \
# 41419  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
#
#        payment_installments  payment_value
# 41419                     8        6929.31

# %% [markdown]
# payment value = price + freight value

# %% [markdown]
# After checking the payment_value for order with order_id='0812eb902a67711a1cb742b3cdaa65ae' and price=6735, it is confirmed that the order is valid. So the outliers in the ‘price’ column are left as they are considered a certain pattern.

# %%
# checking order_id for order with freight_value=409.68
oitems_df[oitems_df['freight_value'] == 409.68]
# Out:
#                                order_id  order_item_id  \
# 73486  a77e1550db865202c56b19ddc6dc4d53              1
#
#                              product_id                         seller_id  \
# 73486  ec31d2a17b299511e7c8627be9337b9b  257e61d3251fb5efb9daadddbc2cf7ca
#
#       shipping_limit_date  price  freight_value
# 73486 2018-04-25 06:55:13  979.0         409.68

# %%
# checking product_category_name and product_weight_g for order with product_id='ec31d2a17b299511e7c8627be9337b9b' and freight_value=409.68
products_df[products_df['product_id'] == 'ec31d2a17b299511e7c8627be9337b9b']
# Out:
#                             product_id product_category_name  \
# 4142  ec31d2a17b299511e7c8627be9337b9b                 bebes
#
#       product_name_lenght  product_description_lenght  product_photos_qty  \
# 4142                 44.0                       385.0                 6.0
#
#       product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 4142           14675.0               55.0               64.0              52.0

# %%
# checking product_category_name_english for order with product_category_name='bebes' and freight_value=409.68
product_category_name_t_df[product_category_name_t_df['product_category_name'] == 'bebes']
# Out:
#    product_category_name product_category_name_english
# 11                 bebes                          baby

# %% [markdown]
# Produk dengan freight_value 409.68 adalah produk pada kategori bayi dengan berat produk 14675g (~15Kg).

# %%
# checking payment_value for order with order_id='a77e1550db865202c56b19ddc6dc4d53' and freight_value=409.68
opayments_df[opayments_df['order_id'] == 'a77e1550db865202c56b19ddc6dc4d53']
# Out:
#                                order_id  payment_sequential payment_type  \
# 71719  a77e1550db865202c56b19ddc6dc4d53                   1  credit_card
#
#        payment_installments  payment_value
# 71719                    12        1388.68

# %% [markdown]
# payment value = price + freight value

# %% [markdown]
# After checking the payment_value for order with order_id='a77e1550db865202c56b19ddc6dc4d53' and freight_value=409.68, it is confirmed that the order is valid. So the outliers in the ‘freight_value’ column are left as they are considered a certain pattern.

# %% [markdown]
# **Insight:**
# - Outliers in the columns ‘order_item_id’, ‘price’, and ‘freight_value’ were left out as they were considered to be specific patterns.

# %% [markdown]
# #### Order Payments Dataset

# %%
# identify outliers more deeply to find out whether the outliers are a specific pattern or an error.
# descriptive analysis
opayments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
# cheking order_id for order with payment_sequential=29
opayments_df[opayments_df['payment_sequential'] == 29]
# Out:
#                                order_id  payment_sequential payment_type  \
# 39108  fa65dad1b0e818e3ccc5cb0e39231352                  29      voucher
#
#        payment_installments  payment_value
# 39108                     1          19.26

# %%
# cheking order_id for order with order_id='fa65dad1b0e818e3ccc5cb0e39231352' and payment_sequential=29
opayments_df[opayments_df['order_id'] == 'fa65dad1b0e818e3ccc5cb0e39231352']
# Out:
#                                 order_id  payment_sequential payment_type  \
# 4885    fa65dad1b0e818e3ccc5cb0e39231352                  27      voucher
# 9985    fa65dad1b0e818e3ccc5cb0e39231352                   4      voucher
# 14321   fa65dad1b0e818e3ccc5cb0e39231352                   1      voucher
# 17274   fa65dad1b0e818e3ccc5cb0e39231352                   9      voucher
# 19565   fa65dad1b0e818e3ccc5cb0e39231352                  10      voucher
# 23074   fa65dad1b0e818e3ccc5cb0e39231352                   2      voucher
# 24879   fa65dad1b0e818e3ccc5cb0e39231352                  25      voucher
# 28330   fa65dad1b0e818e3ccc5cb0e39231352                   5      voucher
# 29648   fa65dad1b0e818e3ccc5cb0e39231352                   6      voucher
# 32519   fa65dad1b0e818e3ccc5cb0e39231352                  11      voucher
# 36822   fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 39108   fa65dad1b0e818e3ccc5cb0e39231352                  29      voucher
# ...

# %%
# cheking price and freight_value for order with order_id='fa65dad1b0e818e3ccc5cb0e39231352' and payment_sequential=29
oitems_df[oitems_df['order_id'] == 'fa65dad1b0e818e3ccc5cb0e39231352']
# Out:
#                                 order_id  order_item_id  \
# 110202  fa65dad1b0e818e3ccc5cb0e39231352              1
#
#                               product_id                         seller_id  \
# 110202  1aecdb5fa3add74e385f25c6c527a462  06532f10282704ef4c69168b914b77be
#
#        shipping_limit_date   price  freight_value
# 110202 2017-04-27 09:10:13  392.55          65.44

# %% [markdown]
# Based on the results above, a customer purchased 1 product with a price of 392.55 and a freight value of 65.44. The customer used 29 different vouchers to pay total payment value. It is confirmed that the order is valid. So the outliers in the ‘payment_sequential’ column are left as they are considered a certain pattern.

# %%
# cheking order_id for order with payment_installments=24
opayments_df[opayments_df['payment_installments'] == 24]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 2970    70b7e94ea46d3e8b5bc12a50186edaf0                   1  credit_card
# 10791   859f516f2fc3f95772e63c5757ab0d5b                   1  credit_card
# 12307   ff36cbc44b8f228e0449c92ef089c843                   1  credit_card
# 18512   2b7dbe9be72b8f9733844c31055c0825                   1  credit_card
# 21713   6ae2e8b8fac02522481d2a2f4ca4412c                   1  credit_card
# 23024   90f864fe19d11549fa01eb81c4dd87e3                   1  credit_card
# 36088   84d2098c97827c6327ed4d7be95e1fc8                   1  credit_card
# 50401   ffb18bf111fa70edf316eb0390427986                   1  credit_card
# 52846   63dbe0c8e63e5f1b4deec09d4f044a7f                   1  credit_card
# 55094   fcbb6af360b31b05460c2c8e524588c0                   1  credit_card
# 60027   ef71772d55431467890fda2f45c7bdde                   1  credit_card
# 63893   d8d5cc8b2d42cce90b7ea35e5691a7b1                   1  credit_card
# ...

# %%
# take one sample
# cheking price and freight_value for order with order_id='84d2098c97827c6327ed4d7be95e1fc8' and 'payment_installments'=24
oitems_df[oitems_df['order_id'] == '84d2098c97827c6327ed4d7be95e1fc8']
# Out:
#                                order_id  order_item_id  \
# 58339  84d2098c97827c6327ed4d7be95e1fc8              1
#
#                              product_id                         seller_id  \
# 58339  73fdc89a7474d12e91ebb4a38341fd84  5bc24d989e71e93c33e50a7782431b0e
#
#       shipping_limit_date  price  freight_value
# 58339 2018-06-07 11:30:36  249.9          36.88

# %% [markdown]
# payment value = price + freight value

# %% [markdown]
# After checking the price and the freight value for order with order_id='84d2098c97827c6327ed4d7be95e1fc8' and 'payment_installments'=24, it is confirmed that the order is valid. So the outliers in the ‘payment_installments’ column are left as they are considered a certain pattern.

# %%
# cheking order_id for order with payment_value=13664.08
opayments_df[opayments_df['payment_value'] == 13664.08]
# Out:
#                                order_id  payment_sequential payment_type  \
# 52107  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
#
#        payment_installments  payment_value
# 52107                     1       13664.08

# %%
# checking price and freight value for order with order_id='03caa2c082116e1d31e67e9ae3700499' and payment_value=13664.08
oitems_df[oitems_df['order_id'] == '03caa2c082116e1d31e67e9ae3700499']
# Out:
#                               order_id  order_item_id  \
# 1647  03caa2c082116e1d31e67e9ae3700499              1
# 1648  03caa2c082116e1d31e67e9ae3700499              2
# 1649  03caa2c082116e1d31e67e9ae3700499              3
# 1650  03caa2c082116e1d31e67e9ae3700499              4
# 1651  03caa2c082116e1d31e67e9ae3700499              5
# 1652  03caa2c082116e1d31e67e9ae3700499              6
# 1653  03caa2c082116e1d31e67e9ae3700499              7
# 1654  03caa2c082116e1d31e67e9ae3700499              8
#
#                             product_id                         seller_id  \
# 1647  5769ef0a239114ac3a854af00df129e4  b37c4c02bda3161a7546a4e6d222d5b2
# 1648  5769ef0a239114ac3a854af00df129e4  b37c4c02bda3161a7546a4e6d222d5b2
# 1649  5769ef0a239114ac3a854af00df129e4  b37c4c02bda3161a7546a4e6d222d5b2
# 1650  5769ef0a239114ac3a854af00df129e4  b37c4c02bda3161a7546a4e6d222d5b2
# 1651  5769ef0a239114ac3a854af00df129e4  b37c4c02bda3161a7546a4e6d222d5b2
# ...

# %% [markdown]
# payment value = price + freight value

# %% [markdown]
# After checking the price and the freight value for order with order_id='03caa2c082116e1d31e67e9ae3700499' and payment_value=13664.08, it is confirmed that the order is valid. So the outliers in the ‘payment_value’ column are left as they are considered a certain pattern.

# %% [markdown]
# **Insight:**
# - Outliers in the columns ‘payment_sequential’, ‘payment_installments’, and ‘payment_value’ were left out as they were considered to be specific patterns.

# %% [markdown]
# #### Order Reviews Dataset

# %%
# handle missing values with 'NaN'
columns_with_missing_values = ['review_comment_title','review_comment_message']
for column in columns_with_missing_values:
    oreviews_df.fillna(value='NaN',inplace=True)

# %%
# recheck missing values
oreviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
# identify outliers more deeply to find out whether the outliers are a specific pattern or an error.
# descriptive analysis
oreviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
# cheking review_comment_title and review_comment_message for review_score=1
oreviews_df[oreviews_df['review_score'] == 1]
# Out:
#                               review_id                          order_id  \
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 19     373cbeecea8286a2b66c97b1b157ec46  583174fbe37d3d5f0d6661be3aad1786
# 29     2c5e27fc178bde7ac173c9c62c31b070  0ce9a24111d850192a933fcaab6fbad3
# 32     58044bca115705a48fe0e00a21390c54  68e55ca79d04a79f20d4bfc0146f4b66
# 39     9fd59cd04b42f600df9f25e54082a8d1  3c314f50bc654f3c4e317b055681dff9
# ...                                 ...                               ...
# 99144  e5a991ae8286f513e512f0f9fd188f9b  fadb25c91522130892be8a5ddb3e139f
# 99155  2fc8295a24978092328d3a329d22940e  e809c167a9cfd31aee1293abe8995065
# 99169  3450ec3bbabeb09a08b00fc72da87a30  c46f950813dd2dd9bab4188dceb83175
# 99184  6cf47345d15e054dd6df872e929bdb27  54e6829fe81bc86cf88b12e6d07ea298
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score     review_comment_title  \
# ...

# %% [markdown]
# After checking the review_comment_title and review_comment_message for review_score=1, the customer seems dissatisfied with the product, so it makes sense that some customers gave a review score of 1.

# %% [markdown]
# **Insight:**
# - Outliers in the columns ‘review_score’ were left out as they were considered to be specific patterns.

# %% [markdown]
# ### Merge Datasets

# %%
# merge orders dataset and order items dataset
orders = pd.merge(orders_df, oitems_df, on='order_id', how='inner')

# %%
# identify number of rows and columns, data types
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   customer_id                    112650 non-null  object
#  2   order_status                   112650 non-null  object
#  3   order_purchase_timestamp       112650 non-null  datetime64[ns]
#  4   order_approved_at              112650 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   112650 non-null  datetime64[ns]
#  6   order_delivered_customer_date  112650 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  112650 non-null  datetime64[ns]
#  8   order_item_id                  112650 non-null  int64
#  9   product_id                     112650 non-null  object
#  10  seller_id                      112650 non-null  object
# ...

# %%
# identify data duplicates
orders.duplicated().sum()
# Out:
# 0

# %%
# identify missing values 
orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# dtype: int64

# %%
# identify outlier
for col in orders.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(orders[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %%
# merge orders dataset and order payments dataset
orders = pd.merge(orders, opayments_df, on='order_id', how='inner')

# %%
# identify number of rows and columns, data types
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117601 entries, 0 to 117600
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       117601 non-null  object
#  1   customer_id                    117601 non-null  object
#  2   order_status                   117601 non-null  object
#  3   order_purchase_timestamp       117601 non-null  datetime64[ns]
#  4   order_approved_at              117601 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   117601 non-null  datetime64[ns]
#  6   order_delivered_customer_date  117601 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  117601 non-null  datetime64[ns]
#  8   order_item_id                  117601 non-null  int64
#  9   product_id                     117601 non-null  object
#  10  seller_id                      117601 non-null  object
# ...

# %%
# identify data duplicates
orders.duplicated().sum()
# Out:
# 0

# %%
# identify missing values 
orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# dtype: int64

# %%
# identify outlier
for col in orders.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(orders[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %%
# merge orders dataset and order reviews dataset
orders = pd.merge(orders, oreviews_df, on='order_id', how='inner')

# %%
# identify number of rows and columns, data types
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       117329 non-null  object
#  1   customer_id                    117329 non-null  object
#  2   order_status                   117329 non-null  object
#  3   order_purchase_timestamp       117329 non-null  datetime64[ns]
#  4   order_approved_at              117329 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   117329 non-null  datetime64[ns]
#  6   order_delivered_customer_date  117329 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  117329 non-null  datetime64[ns]
#  8   order_item_id                  117329 non-null  int64
#  9   product_id                     117329 non-null  object
#  10  seller_id                      117329 non-null  object
# ...

# %%
# identify data duplicates
orders.duplicated().sum()
# Out:
# 0

# %%
# identify missing values 
orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# review_creation_date             0
# review_answer_timestamp          0
# dtype: int64

# %%
# identify outlier
for col in orders.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(orders[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insight:**
# - Orders dataset is the result of merging the order dataset, order item dataset, order payment dataset, and order review dataset.
# - Orders dataset does not contain missing value and data duplicate, but some features have outliers.
# - Outliers in orders dataset were left out as they were considered to be specific patterns.

# %%
# merge products dataset and product category name translation dataset
products = pd.merge(products_df, product_category_name_t_df, on='product_category_name', how='inner')

# %%
# identify number of rows and columns, data types
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32328 entries, 0 to 32327
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_id                     32328 non-null  object
#  1   product_category_name          32328 non-null  object
#  2   product_name_lenght            32328 non-null  float64
#  3   product_description_lenght     32328 non-null  float64
#  4   product_photos_qty             32328 non-null  float64
#  5   product_weight_g               32328 non-null  float64
#  6   product_length_cm              32328 non-null  float64
#  7   product_height_cm              32328 non-null  float64
#  8   product_width_cm               32328 non-null  float64
#  9   product_category_name_english  32328 non-null  object
# dtypes: float64(7), object(3)
# memory usage: 2.7+ MB

# %%
# identify data duplicate
products.duplicated().sum()
# Out:
# 0

# %%
# identify missing values
products.isna().sum()
# Out:
# product_id                       0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# product_category_name_english    0
# dtype: int64

# %%
# identify outlier
for col in products.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(products[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insight:**
# - Products dataset is the result of merging the products dataset and product category name translation dataset.
# - Products dataset does not contain missing values and data duplicate, but some features in products dataset have outliers.
# - Outlier in products dataset were left out as they were considered to be specific patterns.

# %%
# merge customers dataset and orders dataset
customers_orders = pd.merge(customers_df, orders, on='customer_id', how='inner')

# %%
# identify number of rows and columns, data types
customers_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    117329 non-null  object
#  1   customer_unique_id             117329 non-null  object
#  2   customer_zip_code_prefix       117329 non-null  int64
#  3   customer_city                  117329 non-null  object
#  4   customer_state                 117329 non-null  object
#  5   order_id                       117329 non-null  object
#  6   order_status                   117329 non-null  object
#  7   order_purchase_timestamp       117329 non-null  datetime64[ns]
#  8   order_approved_at              117329 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   117329 non-null  datetime64[ns]
#  10  order_delivered_customer_date  117329 non-null  datetime64[ns]
# ...

# %%
# identify data duplicate
customers_orders.duplicated().sum()
# Out:
# 0

# %%
# identify missing values
customers_orders.isna().sum()
# Out:
# customer_id                      0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_id                         0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# review_creation_date             0
# ...

# %%
# identify outliers
for col in customers_orders.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(customers_orders[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insight:**
# - Customers Orders dataset is the result of merging the customers dataset and orders dataset.
# - Customers Orders dataset does not contain missing values and data duplicate, but some features in products dataset have outliers.
# - Outlier in customers orders dataset were left out as they were considered to be specific patterns.

# %%
# merge customers orders dataset and products dataset
e_commerce = pd.merge(customers_orders, products, on='product_id', how='inner')

# %%
# identify number of rows and columns, data types
e_commerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115609 entries, 0 to 115608
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    115609 non-null  object
#  1   customer_unique_id             115609 non-null  object
#  2   customer_zip_code_prefix       115609 non-null  int64
#  3   customer_city                  115609 non-null  object
#  4   customer_state                 115609 non-null  object
#  5   order_id                       115609 non-null  object
#  6   order_status                   115609 non-null  object
#  7   order_purchase_timestamp       115609 non-null  datetime64[ns]
#  8   order_approved_at              115609 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   115609 non-null  datetime64[ns]
#  10  order_delivered_customer_date  115609 non-null  datetime64[ns]
# ...

# %%
# identify data duplicate
e_commerce.duplicated().sum()
# Out:
# 0

# %%
# identify missing values
e_commerce.isna().sum()
# Out:
# customer_id                      0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_id                         0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# review_creation_date             0
# ...

# %%
# identify outliers
for col in e_commerce.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(e_commerce[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insight:**
# - E_Commerce dataset is the result of merging the customers dataset, orders dataset, and products dataset.
# - E_Commerce dataset does not contain missing values and data duplicate, but some features in products dataset have outliers.
# - Outlier in e_commerce dataset were left out as they were considered to be specific patterns.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# customers distribution by city
top_10_customer_cities = (e_commerce.groupby('customer_city')['customer_unique_id']
              .nunique()
              .nlargest(10)
              .reset_index())

# top 10 cities
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_customer_cities, 
            x='customer_city', 
            y='customer_unique_id', palette='viridis')

plt.title('Top 10 Cities by Number of Customers')
plt.xlabel('City')
plt.ylabel('Number of Customers')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - 4 cities—Sao Paulo, Rio de Janeiro, Belo Horizonte, and Brasília—have more than 2,000 customers each.
# - Sao Paulo has the highest number of customers, with 14,529.

# %%
# proportion of customers with repurchase
repurchase_count = e_commerce.groupby('customer_unique_id').customer_id.nunique()

visual_data = pd.DataFrame({'Repurchase Status': ['Single Purchase', 'Repurchase'],
                            'Count': [repurchase_count[repurchase_count == 1].count(),
                                      repurchase_count[repurchase_count > 1].count()]})

plt.figure(figsize=(6, 4))
plt.pie(visual_data['Count'], labels=visual_data['Repurchase Status'], autopct='%1.1f%%', 
        colors=['darkgreen', 'lightgreen'], startangle=140)
plt.title('Proportion of Customers with Repurchase')
plt.show()

# %% [markdown]
# **Inisght:**
# - Only 3% of customers are repeat buyers.

# %%
# order status distribution
order_status_distribution = e_commerce['order_status'].value_counts()

plt.figure(figsize=(12,6))
sns.barplot(x=order_status_distribution.index, 
            y=order_status_distribution.values,
            palette='viridis')

for i, value in enumerate(order_status_distribution.values):
    plt.text(i, value + 0.02 * max(order_status_distribution.values),
             f'{value:,}',
             ha='center', fontsize=10)

plt.title('Order Status Distribution')
plt.xlabel('Orders Status')
plt.ylabel('Number of Orders')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - 97.93% of 115,609 orders have been received by customers.

# %%
# product sales
top_10_product_sales = e_commerce['product_category_name_english'].value_counts().head(10)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_product_sales.values,
            y=top_10_product_sales.index, 
            palette='viridis')
plt.title('Top 10 Product Categories by Sales')
plt.xlabel('Number of Orders')
plt.ylabel('Product Category Name')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Inisght:**
# - 10 product categories sold over 4,000 units.
# - The bed bath table category alone sold 11,847 units.

# %%
# payment type distribution 
payment_type_distribution = e_commerce['payment_type'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=payment_type_distribution.index,
            y=payment_type_distribution.values, 
            palette='viridis')

for i, value in enumerate(payment_type_distribution.values):
    plt.text(i, value + 0.02 * max(payment_type_distribution.values),
             f'{value:,}',
             ha='center', fontsize=10)

plt.title('Payment Type Distribution')
plt.xlabel('Payment Type')
plt.ylabel('Number of Orders')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - 73.75% of the 115,609 orders were paid by credit card, compared to only 1.43% by debit card.

# %%
# reviews score distribution
reviews_score_distribution = e_commerce['review_score'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=reviews_score_distribution.index,
            y=reviews_score_distribution.values, 
            palette='viridis')

plt.title('Reviews Score Distribution')
plt.xlabel('Reviews Score')
plt.ylabel('Number of Reviews')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - More than 80,000 products got a review score of 4 and 5.

# %%
# correlation between price and payment value

plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='payment_value', data=e_commerce, alpha=0.7)
plt.title('Correlation between Price and Payment Value') 
plt.xlabel('Price')
plt.ylabel('Payment Value')
plt.grid(True, linestyle='--', alpha=0.5) 
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - There is a positive trend between price and payment value. This means that the higher the price of a product, the higher the payment made.
# - The data distribution appears quite spread out, especially at lower prices. This indicates that at lower prices, there is a greater variation in payment values, possibly due to factors other than the product price, such as shipping costs, the quantity of items purchased, or discounts.
# - There are some outliers, such as some transactions with relatively low prices but very high payment values. This could be due to large-volume purchases.

# %%
# correlation between freight value and product weight

plt.figure(figsize=(10, 6))
sns.scatterplot(x='product_weight_g', y='freight_value', data=e_commerce, alpha=0.7)
plt.title('Correlation between Freight Value and Product Weight') 
plt.xlabel('Product Weight')
plt.ylabel('Freight Value')
plt.grid(True, linestyle='--', alpha=0.5) 
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - The graph shows a positive trend, although the correlation appears weak. This means that the heavier the product, the higher the shipping cost tends to be.
# - The data distribution appears very dense in the area of low product weight and relatively constant shipping costs. This indicates that most of the products sold have a relatively light weight and standard shipping costs.
# - After the product weight exceeds a certain point (around 10,000), a more significant increase in shipping costs is seen as the weight increases. This indicates a difference in shipping rates for heavier products.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Question 1: How many customers from 2016 to 2018?

# %%
number_of_customers = e_commerce['customer_unique_id'].nunique()
print(f'The number of unique customers from 2016 to 2018: {number_of_customers}')
# Out:
# The number of unique customers from 2016 to 2018: 93396

# %% [markdown]
# **Insight:**
# - There were 93,396 customers who shopped. This number can be used to measure market reach and customer retention.

# %% [markdown]
# ### Question 2: How many orders from 2016 to 2018?

# %%
number_of_orders = e_commerce['order_id'].nunique()
print(f'The number of orders from 2016 to 2018: {number_of_orders}')
# Out:
# The number of orders from 2016 to 2018: 96516

# %% [markdown]
# **Insight::**
# - A total of 96,516 orders were successfully processed in the 2016-2018 period. This figure gives an idea of the transaction activity on the platform.

# %% [markdown]
# ### Question 3: What was the total revenue from 2016 to 2018?

# %%
revenue = e_commerce['payment_value'].sum()
print(f'Total revenue from 2016 to 2018: {revenue}')
# Out:
# Total revenue from 2016 to 2018: 19929532.5

# %%
e_commerce['year'] = e_commerce['order_purchase_timestamp'].dt.year
e_commerce_filtered = e_commerce[e_commerce['year'].isin([2016, 2017, 2018])]
e_commerce_grouped = e_commerce_filtered.groupby('year')['payment_value'].sum().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(e_commerce_grouped['year'], e_commerce_grouped['payment_value'])
plt.title('Revenue From 2016 To 2018')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.xticks(e_commerce_grouped['year'])
plt.show()

# %% [markdown]
# **Insight:**
# - During the 2016-2018 period, total revenue reached 199,295,32.5.
# - The graph shows that total revenue from 2016 to 2018 continues to increase, indicating good financial performance of e-commerce.

# %% [markdown]
# ### Question 4: What was the most purchased product category from 2016 to 2018?

# %%
top_10_product_sales =  e_commerce.groupby('product_category_name_english')['order_item_id'].count().sort_values(ascending=False).head(10)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_product_sales.values,
            y=top_10_product_sales.index,
            palette='Blues')
plt.title('Top 10 Most Purchased Product Categories (2016-2018)')
plt.xlabel('Number of Orders')
plt.ylabel('Product Category Name')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - 10 product categories sold over 4,000 units.
# - The ‘bed bath table’ category is the most purchased product category, with total sales of 11,847 units. This can be a consideration to increase the variety of ‘bed bath table’ products.

# %% [markdown]
# ### Question 5: What was the most used payment method from 2016 to 2018?

# %%
payment_types = e_commerce['payment_type'].value_counts()

plt.figure(figsize=(10,8))
plt.pie(payment_types, 
        labels=payment_types.index, 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=sns.color_palette('Blues'))
plt.title("Payment Method Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Credit card payment is the most commonly used method. This can be a consideration to increase the types of credit cards used, such as Visa, Mastercard, American Express, and JCB.

# %% [markdown]
# ### Question 6: What is the distribution of review scores from 2016 to 2018?

# %%
plt.figure(figsize=(12,8))
sns.histplot(e_commerce['review_score'], bins=5, kde=True) 
plt.title("Distribution of Review Score")
plt.xlabel("Review Score")
plt.ylabel("Frequency")
plt.xticks(range(1, 6))
plt.tight_layout()
plt.show()

print(f'The average review scores: ',e_commerce['review_score'].mean())
# Out:
# The average review scores:  4.034409085797819

# %% [markdown]
# **Inisght:**
# - Customer satisfaction is generally high (average score of 4.03), with the majority of reviews scoring between 4 and 5. However, attention needs to be paid to the 10% of reviews scoring below 4 for quality improvement. The high frequency of scores of 5 (40%) is a positive indicator that needs to be maintained.

# %% [markdown]
# ## Analisis Lanjutan

# %% [markdown]
# ### Customer Segmentation

# %% [markdown]
# Dividing customers into groups based on total payment value can help determine more specific product marketing strategies based on group characteristics.

# %%
# customer segmentation based on payment value
payment_values = e_commerce.groupby('customer_unique_id')['payment_value'].sum().reset_index()

bronze_limit = payment_values['payment_value'].quantile(0.5)
silver_limit = payment_values['payment_value'].quantile(0.9)

def classify_payment(value, bronze, silver):
    if value <= bronze:
        return 'Bronze Customer'
    elif bronze < value <= silver:
        return 'Silver Customer'
    else:
        return 'Golden Customer'

payment_values['customer_group'] = payment_values['payment_value'].apply(lambda x: classify_payment(x, bronze_limit, silver_limit))
customer_group_counts = payment_values['customer_group'].value_counts().reset_index()
customer_group_counts.columns = ['Customer Group', 'Count']

plt.figure(figsize=(8, 6))
plt.bar(customer_group_counts['Customer Group'], customer_group_counts['Count'], color=['brown', 'silver', 'gold'])

for i, value in enumerate(customer_group_counts['Count']):
    plt.text(i, value + 0.5, str(value), ha='center', fontsize=12, color='darkblue')

plt.title('Customer Segmentation Based on Total Payment Value')
plt.xlabel('Customer Group')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0)
plt.show()

print(f'bronze_limit:', bronze_limit)
print(f'silver_limit:', silver_limit)
# Out:
# bronze_limit: 113.03
# silver_limit: 406.51

# %% [markdown]
# **Insight:**
# - Customer segmentation based on total purchase value resulted in three groups: Bronze, Silver, and Golden.
# - The majority of customers are in the Bronze segment.
# - Customers in the bronze group are those who have a total purchase value below 113.03. Product marketing strategies that can be applied such as providing discounts for the first purchase or bundling products.
# - Customers in the silver group are those who have a total purchase value between 113.03 and 406.51. Product marketing strategies that can be applied such as providing special offers for purchasing products at higher prices.
# - Customers in the golden group are those who have a total purchase value above 406.51. Product marketing strategies that can be applied such as providing exclusive services, such as extended warranties or dedicated customer service.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. With 93,396 customers, the e-commerce platform demonstrates a substantial market reach.
# 2. The processing of 96,516 orders signifies a healthy level of transactional activity.
# 3. The increasing total revenue of 199,295,32.5 over the 2016-2018 period demonstrates positive financial growth. This upward trend suggests effective business strategies and increasing market demand.
# 4. The 'bed bath table' category's strong performance, with 11,847 units sold, highlights a significant market demand for these products. This presents an opportunity for further growth within this category.
# 5. The dominance of credit card payments indicates customer preference for this payment method. Optimizing the credit card payment experience is crucial for maximizing conversions.
# 6. A high average review score of 4.03 and a strong presence of 5-star reviews (40%) demonstrate good customer satisfaction. However, addressing the 10% of lower-scoring reviews is essential for continuous improvement.
# 7. Segmenting customers by purchase value allows for targeted marketing strategies. The large Bronze segment presents an opportunity to drive conversions and increase average order value, while the Golden segment requires a focus on retention and loyalty.

# %% [markdown]
# ## Save the E-Commerce Dataset

# %%
# save the e_commerce dataset
e_commerce.to_csv('C:/Users/aniqo/Projects/Submission/e_commerce.csv')
